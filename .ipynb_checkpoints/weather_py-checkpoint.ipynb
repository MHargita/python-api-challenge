# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
! pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/michelledavis/opt/anaconda3/lib/python3.8/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/michelledavis/opt/anaconda3/lib/python3.8/site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

units = "metric"
url = "http://api.openweathermap.org/data/2.5/weather?"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []


###start with city sample



# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %%
cities
# Out:
# ['bambous virieux',
#  'tautira',
#  'busselton',
#  'saint-philippe',
#  'jamestown',
#  'grindavik',
#  'cabo san lucas',
#  'kununurra',
#  'hobart',
#  'kapaa',
#  'east london',
#  'nikolskoye',
#  'dikson',
#  'dingle',
#  'rikitea',
#  'clyde river',
#  'narsaq',
#  'vila',
#  'mar del plata',
#  'bredasdorp',
#  'saint-joseph',
#  'sao jose da coroa grande',
#  'hermanus',
#  'ushuaia',
#  'goderich',
#  'atuona',
#  'tual',
#  'geraldton',
#  'port alfred',
#  'karamea',
#  'saint george',
#  'caluquembe',
#  'albany',
#  'pisco',
#  'araouane',
#  'lebu',
#  'orbetello',
#  'ribeira brava',
#  'arraial do cabo',
#  'yellowknife',
#  'kodiak',
#  'punta arenas',
#  'tuktoyaktuk',
#  'derzhavinsk',
#  'nome',
#  'deputatskiy',
#  'huron',
#  'georgetown',
#  'ribeira grande',
#  'gizo',
#  'attawapiskat',
#  'barrow',
#  'san quintin',
#  'mataura',
#  'avarua',
#  'pevek',
#  'fortuna',
#  'yulara',
#  'toora-khem',
#  'marcona',
#  'kismayo',
#  'sakakah',
#  'cururupu',
#  'varberg',
#  'aksu',
#  'golcuv jenikov',
#  'souillac',
#  'butaritari',
#  'toliary',
#  'seduva',
#  'nouakchott',
#  'barentsburg',
#  'limoux',
#  'beringovskiy',
#  'ternate',
#  'leningradskiy',
#  'zhanakorgan',
#  'port hardy',
#  'te anau',
#  'vaini',
#  'port blair',
#  'cidreira',
#  'port elizabeth',
#  'pousat',
#  'saldanha',
#  'loubomo',
#  'new norfolk',
#  'klaebu',
#  'barra do garcas',
#  'olafsvik',
#  'qasigiannguit',
#  'saleaula',
#  'acapetahua',
#  'kaitangata',
#  'paysandu',
#  'tasiilaq',
#  'dzilam gonzalez',
#  'victoria',
#  'filadelfia',
#  'provideniya',
#  'tarakan',
#  'oranjemund',
#  'amalapuram',
#  'rocha',
#  'bahce',
#  'guerrero negro',
#  'illoqqortoormiut',
#  'hilo',
#  'sire',
#  'madawaska',
#  'hungund',
#  'eureka',
#  'mount gambier',
#  'bathsheba',
#  'bonavista',
#  'tabiauea',
#  'port hedland',
#  'sorvag',
#  'los llanos de aridane',
#  'iordacheanu',
#  'sao filipe',
#  'chara',
#  'acapulco',
#  'mao',
#  'severo-kurilsk',
#  'luocheng',
#  'coquimbo',
#  'sitrah',
#  'hasaki',
#  'bolungarvik',
#  'klaksvik',
#  'ambilobe',
#  'kargasok',
#  'hithadhoo',
#  'katsuura',
#  'mahebourg',
#  'laguna',
#  'sentyabrskiy',
#  'faya',
#  'tazovskiy',
#  'viedma',
#  'yerbogachen',
#  'nuuk',
#  'gari',
#  'codrington',
#  'susangerd',
#  'roald',
#  'sorland',
#  'chuy',
#  'upernavik',
#  'nha trang',
#  'ibra',
#  'thompson',
#  'kasungu',
#  'otradnoye',
#  'puerto ayora',
#  'andra',
#  'gorom-gorom',
#  'rio gallegos',
#  'vila franca do campo',
#  'teguise',
#  'choix',
#  'bengkulu',
#  'anadyr',
#  'tsihombe',
#  'phuket',
#  'spirit river',
#  'xichang',
#  'esperance',
#  'kavieng',
#  'airai',
#  'niamey',
#  'asau',
#  'kashi',
#  'mehamn',
#  'vao',
#  'itoman',
#  'qaanaaq',
#  'scarborough',
#  'adrar',
#  'torbay',
#  'kollumerland',
#  'cayenne',
#  'avera',
#  'mmathubudukwane',
#  'taolanaro',
#  'surt',
#  'fukue',
#  'caravelas',
#  'atamanovka',
#  'yar-sale',
#  'saint-pierre',
#  'mahanje',
#  'chipping sodbury',
#  'castro',
#  'bethel',
#  'salalah',
#  'karauzyak',
#  'longyearbyen',
#  'penzance',
#  'bridlington',
#  'ponta do sol',
#  'chumikan',
#  'kidal',
#  'qui nhon',
#  'kutum',
#  'tupik',
#  'ngukurr',
#  'mrirt',
#  'kerema',
#  'iquitos',
#  'yeppoon',
#  'churapcha',
#  'tura',
#  'boende',
#  'louisbourg',
#  'cachoeira do sul',
#  'oranjestad',
#  'sosva',
#  'adre',
#  'norman wells',
#  'isangel',
#  'edd',
#  'totness',
#  'chokurdakh',
#  'basco',
#  'marzuq',
#  'belushya guba',
#  'coahuayana',
#  'akyab',
#  'vaitupu',
#  'thinadhoo',
#  'khromtau',
#  'bandarbeyla',
#  'bluff',
#  'bure',
#  'ostrovnoy',
#  'port macquarie',
#  'easley',
#  'velingara',
#  'zhigansk',
#  'saint-francois',
#  'ilulissat',
#  'amapa',
#  'gillette',
#  'salice salentino',
#  'voh',
#  'pangnirtung',
#  'hammerfest',
#  'cataguases',
#  'cavan',
#  'viligili',
#  'kuching',
#  'xai-xai',
#  'tooele',
#  'barbar',
#  'russell',
#  'yumen',
#  'amderma',
#  'dolbeau',
#  'tiksi',
#  'fazilka',
#  'eirunepe',
#  'vikarabad',
#  'satitoa',
#  'zhicheng',
#  'richards bay',
#  'tuatapere',
#  'luderitz',
#  'valdivia',
#  'makakilo city',
#  'khandbari',
#  'boa vista',
#  'teahupoo',
#  'hunza',
#  'puerto escondido',
#  'inirida',
#  'mora',
#  'kahului',
#  'liberty',
#  'port moresby',
#  'walvis bay',
#  'nanortalik',
#  'sterling',
#  'kavaratti',
#  'haibowan',
#  'port lincoln',
#  'tecoanapa',
#  'oyama',
#  'tombouctou',
#  'khormuj',
#  'cape town',
#  'lensk',
#  'namibe',
#  'hervey bay',
#  'clarence town',
#  'wasilla',
#  'hailey',
#  'barddhaman',
#  'amuntai',
#  'mozarlandia',
#  'farmington',
#  'acarau',
#  'maues',
#  'pa sang',
#  'george town',
#  'khatanga',
#  'saint anthony',
#  'hambantota',
#  'salinopolis',
#  'malanje',
#  'funadhoo',
#  'play cu',
#  'carnarvon',
#  'wewak',
#  'axim',
#  'palabuhanratu',
#  'fare',
#  'faanui',
#  'hirara',
#  'takoradi',
#  'rognan',
#  'shuyskoye',
#  'lugo',
#  'kamenka',
#  'college',
#  'victoria point',
#  'tezu',
#  'sayyan',
#  'sain alto',
#  'comodoro rivadavia',
#  'usinsk',
#  'grand river south east',
#  'lang son',
#  'si bun ruang',
#  'iqaluit',
#  'shache',
#  'kuche',
#  'padang',
#  'sandwick',
#  'burica',
#  'burley',
#  'saint-georges',
#  'hamilton',
#  'goldap',
#  'tumannyy',
#  'vardo',
#  'zhezkazgan',
#  'lubu',
#  'hami',
#  'broome',
#  'superior',
#  'abu kamal',
#  'puri',
#  'lorengau',
#  'gat',
#  'refojos de basto',
#  'tahe',
#  'krasnoselkup',
#  'inta',
#  'nouadhibou',
#  'puerto madryn',
#  'paralimni',
#  'cherskiy',
#  'zyryanovsk',
#  'husavik',
#  'zivinice',
#  'grand gaube',
#  'cacapava do sul',
#  'weatherford',
#  'numaligarh',
#  'ponsacco',
#  'sibenik',
#  'shingu',
#  'quatre cocos',
#  'jabiru',
#  'bowen',
#  'calama',
#  'don marcelino',
#  'karaul',
#  'matara',
#  'bereda',
#  'slupsk',
#  'north bend',
#  'lagos',
#  'halalo',
#  'shalazhi',
#  'manica',
#  'lulea',
#  'san carlos de bariloche',
#  'ngorongoro',
#  'birjand',
#  'gamba',
#  'xuddur',
#  'pochutla',
#  'hay river',
#  'srednekolymsk',
#  'naziya',
#  'labuhan',
#  'harper',
#  'bonfim',
#  'lompoc',
#  'edremit',
#  'macon',
#  'vestmannaeyjar',
#  'ningan',
#  'mnogovershinnyy',
#  'mahibadhoo',
#  'svetlogorsk',
#  'port augusta',
#  'alofi',
#  'dwarka',
#  'la ronge',
#  'camacha',
#  'inderborskiy',
#  'kijang',
#  'nowy targ',
#  'meulaboh',
#  'atbasar',
#  'balao',
#  'ambodifototra',
#  'weiser',
#  'okhotsk',
#  'warqla',
#  'oksfjord',
#  'labytnangi',
#  'oktyabrskiy',
#  'fernie',
#  'takanosu',
#  'cap malheureux',
#  'nyurba',
#  'vodnyy',
#  'marshfield',
#  'sinnamary',
#  'lasa',
#  'saraland',
#  'oussouye',
#  'oromocto',
#  'novikovo',
#  'lata',
#  'turukhansk',
#  'prado',
#  'mitsamiouli',
#  'kandrian',
#  'puerto rico',
#  'wajima',
#  'tanout',
#  'waipawa',
#  'kieta',
#  'san lorenzo',
#  'karatau',
#  'margate',
#  'bilibino',
#  'san cristobal',
#  'hobyo',
#  'warwick',
#  'hoi an',
#  'bubaque',
#  'maiduguri',
#  'aklavik',
#  'celestun',
#  'pimentel',
#  'vilyuysk',
#  'mana',
#  'shimoda',
#  'samusu',
#  'mys shmidta',
#  'mayo',
#  'constitucion',
#  'luganville',
#  'pipraich',
#  'machaneng',
#  'pampa',
#  'thessalon',
#  'saint-augustin',
#  'chengde',
#  'uruzgan',
#  'kudahuvadhoo',
#  'westport',
#  'karasburg',
#  'bambanglipuro',
#  'malpe',
#  'half moon bay',
#  'ayan',
#  'chabahar',
#  'barcelona',
#  'callaway',
#  'mayya',
#  'port lavaca',
#  'jalalabad',
#  'udachnyy',
#  'poum',
#  'pilar',
#  'uttaradit',
#  'fairbanks',
#  'tubruq',
#  'ulaangom',
#  'hauge',
#  'boyuibe',
#  'abu samrah',
#  'aparecida do taboado',
#  'rio grande',
#  'chilca',
#  'baykit',
#  'solnechnyy',
#  'tigil',
#  'namatanai',
#  'uncia',
#  'geresk',
#  'sabla',
#  'skalistyy',
#  'evans',
#  'otane',
#  'antalya',
#  'kruisfontein',
#  'hofn',
#  'robinson',
#  'san patricio',
#  'honiara',
#  'nemuro',
#  'curuguaty',
#  'lobito',
#  'yamethin',
#  'galich',
#  'pariquera-acu',
#  'terrace bay',
#  'kalmunai',
#  'corralillo',
#  'touros',
#  'jalu',
#  'chagda',
#  'muhos',
#  'mocambique',
#  'korla',
#  'akhtubinsk',
#  'nguiu',
#  'mishkino',
#  'port-gentil',
#  'caraballeda',
#  'markova',
#  'ahipara',
#  'sira',
#  'flin flon',
#  'pacific grove',
#  'itarema',
#  'kuryk',
#  'la rioja',
#  'datong',
#  'ciras',
#  'eugene',
#  'sao joao da barra',
#  'maragogi',
#  'clarksburg',
#  'dongying',
#  'taltal',
#  'coihaique',
#  'whitianga',
#  'teknaf',
#  'alice springs',
#  'easton',
#  'limerick',
#  'prainha',
#  'dunedin',
#  'nsanje',
#  'oistins',
#  'valcourt',
#  'tomatlan',
#  'khonuu',
#  'tucurui',
#  'king city',
#  'bakchar',
#  'praia da vitoria',
#  'kankakee',
#  'maxixe',
#  'mareeba',
#  'kankaanpaa',
#  'guadix',
#  'ozgon',
#  'mahajanga',
#  'manzil tamim',
#  'ustka',
#  'chenghai',
#  'byron bay',
#  'samarai',
#  'kulhudhuffushi',
#  'santiago del estero',
#  'san matias',
#  'simplicio mendes',
#  'tekeli',
#  'laiagam',
#  'betafo',
#  'bayan',
#  'gasa',
#  'dores do indaia',
#  'ndele',
#  'purna',
#  'marrakesh',
#  'tias',
#  'komsomolskiy',
#  'artyom',
#  'phan thiet',
#  'nizhneyansk',
#  'hualmay',
#  'qaqortoq',
#  'petropavlovsk-kamchatskiy',
#  'cockburn town',
#  'bandipur',
#  'prieska',
#  'cortez',
#  'valparaiso',
#  'karaj',
#  'wana',
#  'san rafael']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#weather check
# i inspected the humidity at this step in my city loop

success_counter = 0
humidity = []
wind_speed = []
cloudiness = []
temperature = []
lat = []
long = []
city_name = []

for city in cities:
    response = requests.get(query_url + city)
    response_json = response.json()
    if response_json['cod'] == 200 and response_json['main']['humidity'] < 100:
        success_counter += 1
        humidity.append(response_json['main']['humidity'])
        wind_speed.append(response_json['wind']['speed'])
        cloudiness.append(response_json['clouds']['all'])
        temperature.append(response_json['main']['temp'])
        lat.append(response_json['coord']['lat'])
        long.append(response_json['coord']['lon'])
        city_name.append(response_json['name'])
        
pprint(response_json)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -34.62, 'lon': -68.33},
#  'dt': 1603163027,
#  'id': 3836669,
#  'main': {'feels_like': 12.33,
#           'grnd_level': 939,
#           'humidity': 31,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 15.66,
#           'temp_max': 15.66,
#           'temp_min': 15.66},
#  'name': 'San Rafael',
#  'sys': {'country': 'AR', 'sunrise': 1603187047, 'sunset': 1603234296},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 348, 'speed': 1.64}}

# %%
#Export the city data into a .csv.
#Display the DataFrame

clean_city_df = pd.DataFrame({
    "City": city_name,
    "Latitudes": lat,
    "Longtitudes": long,
    "Humidity": humidity,
    "Wind Speed": wind_speed,
    "Cloudiness": cloudiness,
    "Temperature": temperature,
})
clean_city_df.head()
# Out:
#               City  Latitudes  Longtitudes  Humidity  Wind Speed  Cloudiness  \
# 0  Bambous Virieux     -20.34        57.76        78        5.10          40
# 1          Tautira     -17.73      -149.15        69        8.20          20
# 2        Busselton     -33.65       115.33        34        3.41           1
# 3   Saint-Philippe     -21.36        55.77        49        3.10          36
# 4        Jamestown      42.10       -79.24        93        4.60          90
#
#    Temperature
# 0        23.67
# 1        27.89
# 2        21.90
# 3        20.62
# 4        11.41

# %%
clean_city_df.to_csv("../output_data/cities.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(temperature, lat, marker="o", edgecolors="black", facecolors="teal", alpha=0.75)
plt.title('Temperature vs. Latitude')
plt.xlabel('Temperature')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(humidity, lat, marker="o", edgecolors="black", facecolors="teal", alpha=0.75)
plt.title('Humidity vs. Latitude')
plt.xlabel('Humidity')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(cloudiness, lat, marker="o", edgecolors="black", facecolors="teal", alpha=0.75)
plt.title('Cloudiness vs. Latitude')
plt.xlabel('Cloudiness')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(wind_speed, lat, marker="o", edgecolors="black", facecolors="teal", alpha=0.75)
plt.title('Wind Speed vs. Latitude')
plt.xlabel('wind_speed')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
sorted_city_df = clean_city_df.sort_values("Latitudes", ascending=False)
northern_hemi = sorted_city_df.iloc[0:375,:]
southern_hemi = sorted_city_df.iloc[376:544,:]

northern_lats = northern_hemi["Latitudes"]
southern_lats = southern_hemi["Latitudes"]
northern_temps = northern_hemi["Temperature"]
southern_temps = southern_hemi["Temperature"]
northern_humidity = northern_hemi["Humidity"]
southern_humidity = southern_hemi["Humidity"]
northern_cloudiness = northern_hemi["Cloudiness"]
southern_cloudiness = southern_hemi["Cloudiness"]
northern_wind = northern_hemi["Wind Speed"]
southern_wind = southern_hemi["Wind Speed"]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(northern_temps, northern_lats, marker="o", facecolors="blue", alpha=0.75)
plt.title('Temperature vs. Latitude in the Northern Hemisphere')
plt.xlabel('Temperature')
plt.ylabel('Latitudes')

(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_temps, northern_lats)
regress_values = northern_temps * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(northern_temps,regress_values,"r-")
plt.annotate(line_eq,(-15,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.8267810103812683

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(southern_temps, southern_lats, marker="o", facecolors="red", alpha=0.75)
plt.title('Temperature vs. Latitude in the Southern Hemisphere')
plt.xlabel('Temperature')
plt.ylabel('Latitudes')

(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_temps, southern_lats)
regress_values = southern_temps * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(southern_temps,regress_values,"r-")
plt.annotate(line_eq,(25,-50),fontsize=15,color="blue")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5312775192326109

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(northern_humidity, northern_lats, marker="o", facecolors="blue", alpha=0.75)
plt.title('Humidity vs. Latitude in the Northern Hemisphere')
plt.xlabel('Humidity')
plt.ylabel('Latitudes')


(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_humidity, northern_lats)
regress_values = northern_humidity * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(northern_humidity,regress_values,"r-")
plt.annotate(line_eq,(8,60),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.07459969620054432

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(southern_humidity, southern_lats, marker="o", facecolors="red", alpha=0.75)
plt.title('Humidity vs. Latitude in the Southern Hemisphere')
plt.xlabel('Humidity')
plt.ylabel('Latitudes')

(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_humidity, southern_lats)
regress_values = southern_temps * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(southern_humidity,regress_values,"r-")
plt.annotate(line_eq,(30,-50),fontsize=15,color="blue")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.012004277979182782

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(northern_cloudiness, northern_lats, marker="o", facecolors="blue", alpha=0.75)
plt.title('Cloudiness vs. Latitude in the Northern Hemisphere')
plt.xlabel('Cloudiness')
plt.ylabel('Latitudes')


(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cloudiness, northern_lats)
regress_values = northern_cloudiness * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(northern_cloudiness,regress_values,"r-")
plt.annotate(line_eq,(35,75),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.07435269309330794

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(southern_cloudiness, southern_lats, marker="o", facecolors="red", alpha=0.75)
plt.title('Cloudiness vs. Latitude in the Southern Hemisphere')
plt.xlabel('Cloudiness')
plt.ylabel('Latitudes')


(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cloudiness, southern_lats)
regress_values = southern_cloudiness * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(southern_cloudiness,regress_values,"r-")
plt.annotate(line_eq,(0,-50),fontsize=15,color="blue")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.01241111254297378

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(northern_wind, northern_lats, marker="o", facecolors="blue", alpha=0.75)
plt.title('Wind Speed vs. Latitude in the Northern Hemisphere')
plt.xlabel('Wind Speed')
plt.ylabel('Latitudes')

(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_wind, northern_lats)
regress_values = northern_wind * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(northern_wind,regress_values,"r-")
plt.annotate(line_eq,(10,40),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.013113542554951757

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(southern_wind, southern_lats, marker="o", facecolors="red", alpha=0.75)
plt.title('Wind Speed vs. Latitude in the Southern Hemisphere')
plt.xlabel('Wind Speed')
plt.ylabel('Latitudes')


(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_wind, southern_lats)
regress_values = southern_wind * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(southern_wind,regress_values,"r-")
plt.annotate(line_eq,(0,-55),fontsize=15,color="blue")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.13389219923056236
